# %%
n=int(input('请输入数字的个数，回车结束。'))
i=0
number=[]
total=0
for i in range(n):
    num = int(input('请输入一个数，回车结束。'))
    number.append(num)
    total=total+number[i]
for numb in number:
    print (numb,end = ' ')
print()
print(total)
# Out:
# 请输入数字的个数，回车结束。4
# 请输入一个数，回车结束。2
# 请输入一个数，回车结束。5
# 请输入一个数，回车结束。4
# 请输入一个数，回车结束。1
# 2 5 4 1
# 12

# %%
n=int(input('请输入数字的个数，回车结束。'))
number=[]
for i in range(n):
    num = int(input('请输入一个数，回车结束。'))
    number.append(num)
smallest=number[0]
for i in range(n):
    if number[i]<=smallest:
        smallest=number[i]
print(smallest)
# Out:
# 请输入数字的个数，回车结束。4
# 请输入一个数，回车结束。6
# 请输入一个数，回车结束。5
# 请输入一个数，回车结束。7
# 请输入一个数，回车结束。3
# 3

# %%
n=int(input('请输入数字的个数，回车结束。'))
number=[]
for i in range(n):
    num = int(input('请输入一个数，回车结束。'))
    number.append(num)
n2=int(input('请输入想查询的数字，回车结束。'))
if n2 not in number:
    print('-1')
for i in range(n):
    if n2==number[i]:
        print(i+1)
# Out:
# 请输入数字的个数，回车结束。4
# 请输入一个数，回车结束。6
# 请输入一个数，回车结束。4
# 请输入一个数，回车结束。7
# 请输入一个数，回车结束。2
# 请输入想查询的数字，回车结束。5
# -1

# %%
import math
n1=[]
n2=[]
for i in range(2):
    n = int(input('请输入第一个向量的坐标，第二次回车结束。'))
    n1.append(n)
for i in range(2):
    n = int(input('请输入第二个向量的坐标，第二次回车结束。'))
    n2.append(n)
def A_cos(a,b,c,d):
    a1=n1[0]*n2[0]
    a2=n1[1]*n2[i]
    b1=math.sqrt(n1[0]*n1[0]+n1[1]*n1[1])
    b2=math.sqrt(n1[0]*n1[0]+n1[1]*n1[1])
    cos=(a1+a2)/(b1*b2)
    return(cos)
cos=A_cos(n1[0],n1[1],n2[0],n2[1])
print(cos)
# Out:
# 请输入第一个向量的坐标，第二次回车结束。2
# 请输入第一个向量的坐标，第二次回车结束。5
# 请输入第二个向量的坐标，第二次回车结束。3
# 请输入第二个向量的坐标，第二次回车结束。4
# 0.8965517241379312

# %%
MacBook=[]
num=0
for i in range(5,91):
    for j in range(5,91):
        for k in range(5,91):
            if i+j+k==100:
                MacBook.append(i)
                MacBook.append(j)
                MacBook.append(k)
                MacBook.append('/')
                num=num+1
print(num)
for i in MacBook:
    print(i,end=' ')
# Out:
# 3741
# ...
