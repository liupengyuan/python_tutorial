# %%
import time,random

def easy_sort(seq):
    start_time=time.time()
    for i in range(len(seq)-1):
        min=i
        for j in range (i+1,len(seq)):
            if seq[j]<seq[min]:
                min=j
        seq[i],seq[min]=seq[min],seq[i]
    end_time=time.time()
    print("所用时间为",end_time-start_time)

# %%
def quick_sort(seq):
    p=seq[0]
    left=[]
    right=[]
    for i in range(1,len(seq)):
        if seq[i]<=p:
            left.append(seq[i])
        else: right.append(seq[i])
    if left:
        left=quick_sort(left)
    if right:
        right=quick_sort(right)
    return left+[p]+right
start_time2=time.time()

# %%
numbs=[random.randint(0,100001) for i in range (10000)]
start_time=time.time()
#numbers=sorted(numbs)  #内置函数
#easy_sort(numbs)    #简单排序
#numbers=quick_sort(numbs)  #快速排序
end_time=time.time()
print("所用时间为",end_time-start_time)
#print(numbers)
# Out:
# 所用时间为 0.0

# %%
import random
def count_numbers_dict(seq): #词典法统计
    numbers_dict = {}
    for number in seq:
        if number in numbers_dict:
            numbers_dict[number] += 1   #如果词典中有键为number，则该number的数量+1
        else:  numbers_dict[number] = 1   #否则，词典中加入键number，其数量为1  
    return numbers_dict

#测试用
number=[random.randint(0,100001) for i in range (10000)]
num=sorted(number)  #内置函数排序
table = count_numbers_dict(num)
for i, item in enumerate(table):
    print("数为:",item,"数量为:",table[item])  #item表示为数字，table[item]表示为该数字的数量！！
# Out:
# [45188, 49215, 95283, 81707, 18806, 4482, 64072, 19107, 39353, 20037, 86726, 58712, 84548, 76890, 93239, 61184, 18129, 71986, 5966, 1813, 21897, 12243, 22985, 53395, 11740, 27363, 11041, 9613, 37768, 58444, 97616, 96859, 94105, 73439, 71976, 75596, 86894, 57873, 1379, 41977, 11666, 98259, 24426, 41896, 78936, 31011, 3721, 59241, 16696, 30967, 822, 75521, 920, 72445, 47746, 27746, 54825, 87774, 91598, 95174, 14885, 48282, 12206, 16520, 10236, 50398, 80124, 59756, 50400, 7602, 53913, 42327, 52087, 25972, 50740, 31098, 57782, 13197, 43770, 74747, 66075, 89141, 78737, 79961, 93978, 67115, 31932, 39003, 34848, 96208, 71114, 56134, 70833, 22126, 44249, 18506, 9147, 7871, 15488, 89283, 76417, 23203, 74878, 89197, 20652, 6874, 86120, 94627, 74822, 82765, 42592, 41195, 78083, 3934, 56586, 36920, 30333, 75911, 73719, 97681, 40072, 20244, 83135, 82833, 10242, 21439, 76242, 26302, 58983, 49257, 46367, 53862, 47064, 66321, 45186, 41997, 27434, 29059, 88130, 57045, 98068, 15879, 24004, 66401, 9591
# ...
