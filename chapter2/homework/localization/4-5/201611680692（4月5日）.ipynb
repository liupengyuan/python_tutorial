# %%
import math
def pfg(sum):
    jieguo=math.sqrt(sum)
    print(jieguo)

import random
n=int (input())
print("输入的数字第一个比第二个小")
m=int (input())
k=int (input())
i=0
number=0
sum=0
while i<n:
    number=random.randint(m,k)
    sum=sum+number
    i=i+1
total=sum/n

pfg(total)
# Out:
# 5
# 输入的数字第一个比第二个小
# 84
# 102
# 9.818350166906862

# %%
import math
import random
n=int (input())
print("输入的数字第一个比第二个小")
m=int (input())
k=int (input())
i=0
number=0
sum1=0
sum2=0
while i<n:
    number=random.randint(m,k)
    sum1=sum1+math.log10(number)
    sum2=sum2+1/math.log10(number)
    i=i+1
print(sum1,sum2)
# Out:
# 6
# 输入的数字第一个比第二个小
# 84
# 102
# 11.714492009083735 3.0738148163066716

# %%
import random
n= int (input())
a=random.randint(1,9)
i=1
sum=a
while i<n:
    a=a+a*10**i
    sum=sum+a
    i+=1
print(sum)
# Out:
# 5
# 44493341380

# %%
import random, math


def menu():
    print('=====游戏菜单=====')
    print('1. 游戏说明')
    print('2. 开始游戏')
    print('3. 退出游戏')
    print('4. 制作团队')
    print('=====游戏菜单=====')


def win():
    print(
              '''
           ======恭喜你，你赢了=======
        
    
                ."".    ."",
                |  |   /  /
                |  |  /  /
                |  | /  /
                |  |/  ;-._ 
                }  ` _/  / ;
                |  /` ) /  /
                | /  /_/\_/\
                |/  /      |
                (  ' \ '-  |
                 \    `.  /
                  |      |
                  |      |
          
          ======恭喜你，你赢了=======
        '''
              )

def lose():
    print(
                '''
           ======YOU LOSE=======
        
    
                

                   .-"      "-.
                  /            \
                 |              |
                 |,  .-.  .-.  ,|
                 | )(__/  \__)( |
                 |/     /\     \|
       (@_       (_     ^^     _)
  _     ) \_______\__|IIIIII|__/__________________________
 (_)@8@8{}<________|-\IIIIII/-|___________________________>
        )_/        \          /
       (@           `--------`
       
       
       
          ======YOU LOSE=======
        '''
                )

def gameover():
    print(
        '''
           ======GAME OVER=======
        
             _________ 
            / ======= \ 
           / __________\ 
          | ___________ | 
          | | -       | | 
          | |         | | 
          | |_________| |________________ 
          \=____________/                ) 
          / """"""""""" \               / 
         / ::::::::::::: \          =D-' 
        (_________________) 

       
          ======GAME OVER=======
        '''
    )


def show_team():
    print("hahaha")

def show_instruction():
    print("没有！")


def guessgame():
    n=int (input("请输入一个大于0的数作为上限"))
    number=int (input())
    max_times=10
    guess_times=0
    daiding1=n
    daiding2=1
        

    while guess_times+1<=max_times:
        guess=random.randint(daiding2,daiding1)
        guess_times+=1
        print(guess)

        if guess==number:
            win()
            print(guess)
            break
        elif guess>number:
            print("大了！")
            if guess<daiding1:
                daiding1=guess
            
        else:
            print("小了！")
            if guess>daiding2:
                daiding2=guess
    else:
        lose()



def main():
    while True:
        menu()
        choice=int(input())
        if choice==1:
            show_intruction()
        elif choice==2:
            guessgame()
        elif choice==3:
            gameover()
            break
        else:
            show_team()
            

if __name__ == '__main__':
    main()
# Out:
# =====游戏菜单=====
# 1. 游戏说明
# 2. 开始游戏
# 3. 退出游戏
# 4. 制作团队
# =====游戏菜单=====
# 2
# 请输入一个大于0的数作为上限84
# 53
# 23
# 小了！
# 44
# 小了！
# 56
# 大了！
# 51
# 小了！
# 56
# 大了！
# 56
# 大了！
# 53
#
#            ======恭喜你，你赢了=======
#
#
#                 ."".    ."",
#                 |  |   /  /
#                 |  |  /  /
#                 |  | /  /
#                 |  |/  ;-._
#                 }  ` _/  / ;
#                 |  /` ) /  /
#                 | /  /_/\_/                |/  /      |
#                 (  ' \ '-  |
#                  \    `.  /
#                   |      |
#                   |      |
#
#           ======恭喜你，你赢了=======
#
# 53
# =====游戏菜单=====
# 1. 游戏说明
# 2. 开始游戏
# 3. 退出游戏
# 4. 制作团队
# =====游戏菜单=====
