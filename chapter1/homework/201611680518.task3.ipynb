# %%
max_number1 =0
max_number2 =0

i = 0
while i <= 3:
    i += 1
    n = int(input('请输入一个整数，回车结束'))
    if n > max_number1:
        max_number2 =max_number1
        max_number1 = n
       
    elif n > max_number2:
            max_number2 =n 

print('次大值是：', max_number2)
# Out:
# 请输入一个整数，回车结束2
# 请输入一个整数，回车结束5
# 请输入一个整数，回车结束4
# 请输入一个整数，回车结束6
# 次大值是： 5
